# %% [markdown]
# # Netflix Advanced Structures Interactive Demo
#
# Este notebook ya no es solo una coleccion de benchmarks. Ahora abre una **demo funcional e interactiva** compatible con Google Colab.
#
# ## Que puedes hacer
# - escribir y ver **autocompletado** inmediato con `Trie`
# - consultar **usuarios similares** con `MinHash + LSH`
# - registrar accesos y observar un **cache LRU inteligente**
# - encolar y procesar eventos con **prioridades**
# - detectar **duplicados/anomalias** con `Bloom Filter` y `Count-Min Sketch`
# - actualizar el **Top-K** en tiempo real con `Misra-Gries`
#
# Debajo de la parte interactiva queda una celda opcional para correr los benchmarks y generar evidencia empirica y graficas.

# %%
# %pip -q install ipywidgets pandas matplotlib numpy

# %%
from pathlib import Path

module_path = Path('netflix_advanced_structures_demo.py')
if not module_path.exists():
    raise FileNotFoundError(
        'Falta netflix_advanced_structures_demo.py. Sube este notebook y el modulo al mismo entorno de Colab.'
    )

from netflix_advanced_structures_demo import launch_interactive_colab_demo, run_colab_demo

print('Entorno listo.')

# %% [markdown]
# ## Demo interactiva
#
# Ejecuta la siguiente celda para abrir la interfaz. Cada pestana corresponde a una funcionalidad de la consigna.

# %%
app = launch_interactive_colab_demo(catalog_size=3000, cache_capacity=12, topk_k=10, show=False)
app

# %% [markdown]
# ## Evidencia empirica
#
# La siguiente celda es opcional. Ejecutala si quieres las tablas y graficas comparativas para sustentar el uso correcto y eficiente de las estructuras.

# %%
results = run_colab_demo()
